# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyJais/Quantum-Computing/blob/main/2348558_QC_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 42.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 7.6 MB/s eta 0:00:00
# ...

# %%
import qiskit
from numpy import sqrt
from qiskit.quantum_info import Statevector, Operator
from IPython.display import display

# %% [markdown]
# ![Screenshot 2024-10-24 at 11.10.51 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-24 at 11.11.08 AM.png](data:image/png;base64,...)

# %%
X = Operator([[0, 1], [1, 0]])
Y = Operator([[0, -1.0j], [1.0j, 0]])
Z = Operator([[1, 0], [0, -1]])
H = Operator([[1 / sqrt(2), 1 / sqrt(2)], [1 / sqrt(2), -1 / sqrt(2)]])
S = Operator([[1, 0], [0, 1.0j]])
T = Operator([[1, 0], [0, (1 + 1.0j) / sqrt(2)]])

operations = [X, Y, Z, H, S, T]
v = Statevector([1, 0])

# %%
for i, op in enumerate(operations):
    print(f"Step {i}:")
    print("Initial State:")
    display(v.draw('latex'))
    print(f"Operation Applied:")
    display(op.draw('latex'))

    v = v.evolve(op)

    print("New State:")
    display(v.draw('latex'))
    print("-" * 100)
# Out:
# Step 0:
# Initial State:
# $$ |0\rangle$$
# Operation Applied:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  1 & 0  \\
#  \end{bmatrix}
# $$
# New State:
# $$ |1\rangle$$
# ----------------------------------------------------------------------------------------------------
# Step 1:
# Initial State:
# $$ |1\rangle$$
# Operation Applied:
# $$
#
# \begin{bmatrix}
# 0 & - i  \\
#  i & 0  \\
#  \end{bmatrix}
# $$
# New State:
# $$- i |0\rangle$$
# ----------------------------------------------------------------------------------------------------
# Step 2:
# Initial State:
# $$- i |0\rangle$$
# Operation Applied:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  0 & -1  \\
#  \end{bmatrix}
# $$
# New State:
# $$- i |0\rangle$$
# ----------------------------------------------------------------------------------------------------
# Step 3:
# Initial State:
# $$- i |0\rangle$$
# Operation Applied:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
# ...

# %%
from qiskit import QuantumCircuit

circuit = QuantumCircuit(1)

circuit.h(0)
circuit.t(0)
circuit.h(0)
circuit.t(0)
circuit.z(0)

circuit.draw()
# Out:
#    ┌───┐┌───┐┌───┐┌───┐┌───┐
# q: ┤ H ├┤ T ├┤ H ├┤ T ├┤ Z ├
#    └───┘└───┘└───┘└───┘└───┘

# %%
ket0 = Statevector([1, 0])
v = ket0.evolve(circuit)
display(v.draw("text"))
display(v.draw("latex"))
# Out:
# [ 0.85355339+0.35355339j,-0.35355339+0.14644661j]
# $$(0.8535533906 + 0.3535533906 i) |0\rangle+(-0.3535533906 + 0.1464466094 i) |1\rangle$$

# %%
from qiskit.visualization import plot_histogram
statistics = v.sample_counts(4000)
plot_histogram(statistics)
